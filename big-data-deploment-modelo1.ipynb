# %%
#declaração das bibliotecas

import pandas as pd
import mlflow
import statsmodels.api as sm
import json
import requests
import matplotlib.pyplot as plt

# %%
#caminho do dataset
caminho ="data/tempodist.csv"

#carregando o dataset
df_tempodist = pd.read_csv(caminho)

df_tempodist
# Out:
#    tempo  distancia
# 0     15          8
# 1     20          6
# 2     20         15
# 3     40         20
# 4     50         25
# 5     25         11
# 6     10          5
# 7     55         32
# 8     35         28
# 9     30         20

# %%
#veriicando as variáveis descritivas das colunas
df_tempodist.describe()
# Out:
#           tempo  distancia
# count  10.00000  10.000000
# mean   30.00000  17.000000
# std    14.90712   9.510228
# min    10.00000   5.000000
# 25%    20.00000   8.750000
# 50%    27.50000  17.500000
# 75%    38.75000  23.750000
# max    55.00000  32.000000

# %%
#treinando um modelo localmente

modelo_nulo_local = sm.OLS.from_formula(
    formula="tempo ~ distancia", data=df_tempodist
).fit()

# %%
#veriicando seu output

modelo_nulo_local.summary()
# Out:
# d:\Documentos\Projetos\MBAdsa_bigdata_dp\bigdata_deploymodelos\Lib\site-packages\scipy\stats\_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=10 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  tempo   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     36.30
# Date:                Thu, 24 Oct 2024   Prob (F-statistic):           0.000314
# Time:                        23:24:37   Log-Likelihood:                -32.123
# No. Observations:                  10   AIC:                             68.25
# Df Residuals:                       8   BIC:                             68.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.8784      4.532      1.297      0.231      -4.573      16.330
# distancia      1.4189      0.235      6.025      0.000       0.876       1.962
# ==============================================================================
# Omnibus:                        1.016   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.602   Jarque-Bera (JB):                0.694
# Skew:                          -0.262   Prob(JB):                        0.707
# Kurtosis:                       1.820   Cond. No.                         41.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Nesta parte inicializaremos o MLFLOW

mlflow.set_tracking_uri("http://localhost:5000")

# %%
#criando nosso primeiro experimento
mlflow.set_experiment(experiment_name="Regressão Linear Simples - tempodist")
# Out:
# 2024/10/24 23:27:45 INFO mlflow.tracking.fluent: Experiment with name 'Regressão Linear Simples - tempodist' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/486145605123477232', creation_time=1729823265207, experiment_id='486145605123477232', last_update_time=1729823265207, lifecycle_stage='active', name='Regressão Linear Simples - tempodist', tags={}>
